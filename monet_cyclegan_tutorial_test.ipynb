# %% [markdown]
# <a href="https://colab.research.google.com/github/TomJiX/ML_start/blob/main/monet_cyclegan_tutorial_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction and Setup
#
# This notebook utilizes a CycleGAN architecture to add Monet-style to photos. For this tutorial, we will be using the TFRecord dataset. Import the following packages and change the accelerator to TPU.
#
# For more information, check out [TensorFlow](https://www.tensorflow.org/tutorials/generative/cyclegan) and [Keras](https://keras.io/examples/generative/cyclegan/) CycleGAN documentation pages.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Device: grpc://10.15.139.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.15.139.66:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.15.139.66:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Number of replicas: 8
# 2.3.0

# %% [markdown]
# # Load in the data
#
# We want to keep our photo dataset and our Monet dataset separate. First, load in the filenames of the TFRecords.

# %%
GCS_PATH = "gs://kds-bb6228c9acff063fb652943d92bd2cbbd3d4826d1a8908e61e937c4f"

# %%
MONET_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/monet_tfrec/*.tfrec'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/photo_tfrec/*.tfrec'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20

# %% [markdown]
# All the images for the competition are already sized to 256x256. As these images are RGB images, set the channel to 3. Additionally, we need to scale the images to a [-1, 1] scale. Because we are building a generative model, we don't need the labels or the image id so we'll only return the image from the TFRecord.

# %%
IMAGE_SIZE = [256, 256]

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    return image

# %% [markdown]
# Define the function to extract the image from the files.

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    return dataset

# %% [markdown]
# Let's load in our datasets.

# %%
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1)

# %%
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %% [markdown]
# Let's  visualize a photo example and a Monet example.

# %%
plt.subplot(121)
plt.title('Photo')
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Monet')
plt.imshow(example_monet[0] * 0.5 + 0.5)

# %% [markdown]
# # Build the generator
#
# We'll be using a UNET architecture for our CycleGAN. To build our generator, let's first define our `downsample` and `upsample` methods.
#
# The `downsample`, as the name suggests, reduces the 2D dimensions, the width and height, of the image by the stride. The stride is the length of the step the filter takes. Since the stride is 2, the filter is applied to every other pixel, hence reducing the weight and height by 2.
#
# We'll be using an instance normalization instead of batch normalization. As the instance normalization is not standard in the TensorFlow API, we'll use the layer from TensorFlow Add-ons.

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %% [markdown]
# `Upsample` does the opposite of downsample and increases the dimensions of the of the image. `Conv2DTranspose` does basically the opposite of a `Conv2D` layer.

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %% [markdown]
# Let's build our generator!
#
# The generator first downsamples the input image and then upsample while establishing long skip connections. Skip connections are a way to help bypass the vanishing gradient problem by concatenating the output of a layer to multiple layers instead of only one. Here we concatenate the output of the downsample layer to the upsample layer in a symmetrical fashion.

# %%
def Generator():
    inputs = layers.Input(shape=[256,256,3])

    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# # Build the discriminator
#
# The discriminator takes in the input image and classifies it as real or fake (generated). Instead of outputing a single node, the discriminator outputs a smaller 2D image with higher pixel values indicating a real classification and lower values indicating a fake classification.

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %%
with strategy.scope():
    monet_generator = Generator() # transforms photos to Monet-esque paintings
    photo_generator = Generator() # transforms Monet paintings to be more like photos

    monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
    photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %% [markdown]
# Since our generators are not trained yet, the generated Monet-esque photo does not show what is expected at this point.

# %%
to_monet = monet_generator(example_photo)

plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(example_photo[0] * 0.5 + 0.5)

plt.subplot(1, 2, 2)
plt.title("Monet-esque Photo")
plt.imshow(to_monet[0] * 0.5 + 0.5)
plt.show()

# %% [markdown]
# # Build the CycleGAN model
#
# We will subclass a `tf.keras.Model` so that we can run `fit()` later to train our model. During the training step, the model transforms a photo to a Monet painting and then back to a photo. The difference between the original photo and the twice-transformed photo is the cycle-consistency loss. We want the original photo and the twice-transformed photo to be similar to one another.
#
# The losses are defined in the next section.

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %% [markdown]
# # Define loss functions
#
# The discriminator loss function below compares real images to a matrix of 1s and fake images to a matrix of 0s. The perfect discriminator will output all 1s for real images and all 0s for fake images. The discriminator loss outputs the average of the real and generated loss.

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %% [markdown]
# The generator wants to fool the discriminator into thinking the generated image is real. The perfect generator will have the discriminator output only 1s. Thus, it compares the generated image to a matrix of 1s to find the loss.

# %%
with strategy.scope():
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %% [markdown]
# We want our original photo and the twice transformed photo to be similar to one another. Thus, we can calculate the cycle consistency loss be finding the average of their difference.

# %%
with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %% [markdown]
# The identity loss compares the image with its generator (i.e. photo with photo generator). If given a photo as input, we want it to generate the same image as the image was originally a photo. The identity loss compares the input with the output of the generator.

# %%
with strategy.scope():
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %% [markdown]
# # Train the CycleGAN
#
# Let's compile our model. Since we used `tf.keras.Model` to build our CycleGAN, we can just ude the `fit` function to train our model.

# %%
with strategy.scope():
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
with strategy.scope():
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=120
)
# Out:
# Epoch 1/120
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 5.2372 - photo_gen_loss: 5.4295 - monet_disc_loss: 0.6445 - photo_disc_loss: 0.6133
# Epoch 2/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.7413 - photo_gen_loss: 3.7830 - monet_disc_loss: 0.6381 - photo_disc_loss: 0.6351
# Epoch 3/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 3.5806 - photo_gen_loss: 3.6625 - monet_disc_loss: 0.6528 - photo_disc_loss: 0.6235
# Epoch 4/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.4479 - photo_gen_loss: 3.5481 - monet_disc_loss: 0.6462 - photo_disc_loss: 0.6185
# Epoch 5/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 3.2756 - photo_gen_loss: 3.3591 - monet_disc_loss: 0.6382 - photo_disc_loss: 0.6164
# Epoch 6/120
# 300/300 [==============================] - 58s 193ms/step - monet_gen_loss: 3.1765 - photo_gen_loss: 3.2310 - monet_disc_loss: 0.6237 - photo_disc_loss: 0.6064
# Epoch 7/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.1840 - photo_gen_loss: 3.2401 - monet_disc_loss: 0.6066 - photo_disc_loss: 0.5941
# Epoch 8/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 3.2115 - photo_gen_loss: 3.2355 - monet_disc_loss: 0.6047 - photo_disc_loss: 0.6117
# Epoch 9/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 3.2101 - photo_gen_loss: 3.2420 - monet_disc_loss: 0.6017 - photo_disc_loss: 0.6099
# Epoch 10/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 3.1832 - photo_gen_loss: 3.1724 - monet_disc_loss: 0.5986 - photo_disc_loss: 0.6157
# Epoch 11/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 3.1253 - photo_gen_loss: 3.1461 - monet_disc_loss: 0.6136 - photo_disc_loss: 0.6143
# Epoch 12/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.0706 - photo_gen_loss: 3.0999 - monet_disc_loss: 0.6147 - photo_disc_loss: 0.6122
# Epoch 13/120
# 300/300 [==============================] - 58s 193ms/step - monet_gen_loss: 3.0394 - photo_gen_loss: 3.0691 - monet_disc_loss: 0.6112 - photo_disc_loss: 0.6130
# Epoch 14/120
# 300/300 [==============================] - 58s 192ms/step - monet_gen_loss: 2.9908 - photo_gen_loss: 3.0246 - monet_disc_loss: 0.6129 - photo_disc_loss: 0.6137
# Epoch 15/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.9529 - photo_gen_loss: 2.9988 - monet_disc_loss: 0.6150 - photo_disc_loss: 0.6130
# Epoch 16/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.9167 - photo_gen_loss: 2.9632 - monet_disc_loss: 0.6166 - photo_disc_loss: 0.6184
# Epoch 17/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.8777 - photo_gen_loss: 2.9097 - monet_disc_loss: 0.6155 - photo_disc_loss: 0.6194
# Epoch 18/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.8521 - photo_gen_loss: 2.8831 - monet_disc_loss: 0.6159 - photo_disc_loss: 0.6168
# Epoch 19/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.8345 - photo_gen_loss: 2.8659 - monet_disc_loss: 0.6159 - photo_disc_loss: 0.6150
# Epoch 20/120
# 300/300 [==============================] - 58s 193ms/step - monet_gen_loss: 2.8068 - photo_gen_loss: 2.8330 - monet_disc_loss: 0.6199 - photo_disc_loss: 0.6185
# Epoch 21/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7862 - photo_gen_loss: 2.8061 - monet_disc_loss: 0.6211 - photo_disc_loss: 0.6165
# Epoch 22/120
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 2.7599 - photo_gen_loss: 2.7959 - monet_disc_loss: 0.6246 - photo_disc_loss: 0.6153
# Epoch 23/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.7407 - photo_gen_loss: 2.7747 - monet_disc_loss: 0.6239 - photo_disc_loss: 0.6166
# Epoch 24/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.7123 - photo_gen_loss: 2.7488 - monet_disc_loss: 0.6308 - photo_disc_loss: 0.6205
# Epoch 25/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.7076 - photo_gen_loss: 2.7419 - monet_disc_loss: 0.6276 - photo_disc_loss: 0.6179
# Epoch 26/120
# 300/300 [==============================] - 60s 200ms/step - monet_gen_loss: 2.6827 - photo_gen_loss: 2.7241 - monet_disc_loss: 0.6262 - photo_disc_loss: 0.6211
# Epoch 27/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.6645 - photo_gen_loss: 2.7062 - monet_disc_loss: 0.6284 - photo_disc_loss: 0.6198
# Epoch 28/120
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 2.6296 - photo_gen_loss: 2.6761 - monet_disc_loss: 0.6348 - photo_disc_loss: 0.6272
# Epoch 29/120
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 2.6190 - photo_gen_loss: 2.6564 - monet_disc_loss: 0.6315 - photo_disc_loss: 0.6273
# Epoch 30/120
# 300/300 [==============================] - 61s 203ms/step - monet_gen_loss: 2.6092 - photo_gen_loss: 2.6581 - monet_disc_loss: 0.6317 - photo_disc_loss: 0.6264
# Epoch 31/120
# 300/300 [==============================] - 61s 203ms/step - monet_gen_loss: 2.5833 - photo_gen_loss: 2.6287 - monet_disc_loss: 0.6302 - photo_disc_loss: 0.6269
# Epoch 32/120
# 300/300 [==============================] - 60s 200ms/step - monet_gen_loss: 2.5401 - photo_gen_loss: 2.6173 - monet_disc_loss: 0.6361 - photo_disc_loss: 0.6226
# Epoch 33/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.6024 - photo_gen_loss: 2.6755 - monet_disc_loss: 0.6225 - photo_disc_loss: 0.6119
# Epoch 34/120
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 2.5585 - photo_gen_loss: 2.6503 - monet_disc_loss: 0.6332 - photo_disc_loss: 0.6182
# Epoch 35/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.4881 - photo_gen_loss: 2.5615 - monet_disc_loss: 0.6371 - photo_disc_loss: 0.6222
# Epoch 36/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7232 - photo_gen_loss: 2.7472 - monet_disc_loss: 0.5824 - photo_disc_loss: 0.5790
# Epoch 37/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.5166 - photo_gen_loss: 2.6289 - monet_disc_loss: 0.6389 - photo_disc_loss: 0.6129
# Epoch 38/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.5135 - photo_gen_loss: 2.6341 - monet_disc_loss: 0.6331 - photo_disc_loss: 0.6083
# Epoch 39/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.4556 - photo_gen_loss: 2.5617 - monet_disc_loss: 0.6319 - photo_disc_loss: 0.6147
# Epoch 40/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 2.4477 - photo_gen_loss: 2.5602 - monet_disc_loss: 0.6289 - photo_disc_loss: 0.6101
# Epoch 41/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.5827 - photo_gen_loss: 2.6683 - monet_disc_loss: 0.6111 - photo_disc_loss: 0.6005
# Epoch 42/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.5439 - photo_gen_loss: 2.6314 - monet_disc_loss: 0.6170 - photo_disc_loss: 0.6020
# Epoch 43/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.4641 - photo_gen_loss: 2.5598 - monet_disc_loss: 0.6204 - photo_disc_loss: 0.6073
# Epoch 44/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.5661 - photo_gen_loss: 2.6458 - monet_disc_loss: 0.6031 - photo_disc_loss: 0.5958
# Epoch 45/120
# 300/300 [==============================] - 58s 193ms/step - monet_gen_loss: 2.5151 - photo_gen_loss: 2.6099 - monet_disc_loss: 0.6164 - photo_disc_loss: 0.5992
# Epoch 46/120
# 300/300 [==============================] - 58s 192ms/step - monet_gen_loss: 2.4260 - photo_gen_loss: 2.5278 - monet_disc_loss: 0.6193 - photo_disc_loss: 0.6014
# Epoch 47/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 2.6842 - photo_gen_loss: 2.7393 - monet_disc_loss: 0.5743 - photo_disc_loss: 0.5661
# Epoch 48/120
# 300/300 [==============================] - 60s 198ms/step - monet_gen_loss: 2.4842 - photo_gen_loss: 2.6103 - monet_disc_loss: 0.6245 - photo_disc_loss: 0.5968
# Epoch 49/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.6560 - photo_gen_loss: 2.7974 - monet_disc_loss: 0.5907 - photo_disc_loss: 0.5541
# Epoch 50/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.6547 - photo_gen_loss: 2.8286 - monet_disc_loss: 0.6055 - photo_disc_loss: 0.5734
# Epoch 51/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.6064 - photo_gen_loss: 2.7245 - monet_disc_loss: 0.6032 - photo_disc_loss: 0.5763
# Epoch 52/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.5835 - photo_gen_loss: 2.6958 - monet_disc_loss: 0.5996 - photo_disc_loss: 0.5834
# Epoch 53/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7014 - photo_gen_loss: 2.8726 - monet_disc_loss: 0.5834 - photo_disc_loss: 0.5466
# Epoch 54/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.5482 - photo_gen_loss: 2.7091 - monet_disc_loss: 0.6063 - photo_disc_loss: 0.5772
# Epoch 55/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.6335 - photo_gen_loss: 2.7387 - monet_disc_loss: 0.5898 - photo_disc_loss: 0.5659
# Epoch 56/120
# 300/300 [==============================] - 58s 193ms/step - monet_gen_loss: 2.6306 - photo_gen_loss: 2.7226 - monet_disc_loss: 0.5931 - photo_disc_loss: 0.5728
# Epoch 57/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.7374 - photo_gen_loss: 2.8393 - monet_disc_loss: 0.5463 - photo_disc_loss: 0.5258
# Epoch 58/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7317 - photo_gen_loss: 2.8189 - monet_disc_loss: 0.5954 - photo_disc_loss: 0.5663
# Epoch 59/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.5768 - photo_gen_loss: 2.6834 - monet_disc_loss: 0.5981 - photo_disc_loss: 0.5762
# Epoch 60/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.5115 - photo_gen_loss: 2.6184 - monet_disc_loss: 0.6018 - photo_disc_loss: 0.5829
# Epoch 61/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.5406 - photo_gen_loss: 2.6270 - monet_disc_loss: 0.5970 - photo_disc_loss: 0.5827
# Epoch 62/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.6214 - photo_gen_loss: 2.6875 - monet_disc_loss: 0.5880 - photo_disc_loss: 0.5756
# Epoch 63/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.7977 - photo_gen_loss: 2.8472 - monet_disc_loss: 0.5537 - photo_disc_loss: 0.5496
# Epoch 64/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.7620 - photo_gen_loss: 2.8282 - monet_disc_loss: 0.5713 - photo_disc_loss: 0.5590
# Epoch 65/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 2.6289 - photo_gen_loss: 2.7118 - monet_disc_loss: 0.5781 - photo_disc_loss: 0.5727
# Epoch 66/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.6602 - photo_gen_loss: 2.7129 - monet_disc_loss: 0.5760 - photo_disc_loss: 0.5705
# Epoch 67/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.8722 - photo_gen_loss: 2.8603 - monet_disc_loss: 0.5475 - photo_disc_loss: 0.5513
# Epoch 68/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.8025 - photo_gen_loss: 2.7864 - monet_disc_loss: 0.5484 - photo_disc_loss: 0.5599
# Epoch 69/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.6866 - photo_gen_loss: 2.7390 - monet_disc_loss: 0.5673 - photo_disc_loss: 0.5650
# Epoch 70/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.1537 - photo_gen_loss: 3.0129 - monet_disc_loss: 0.4653 - photo_disc_loss: 0.4838
# Epoch 71/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.9204 - photo_gen_loss: 2.9092 - monet_disc_loss: 0.5711 - photo_disc_loss: 0.5570
# Epoch 72/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.6980 - photo_gen_loss: 2.7523 - monet_disc_loss: 0.5757 - photo_disc_loss: 0.5636
# Epoch 73/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.6478 - photo_gen_loss: 2.6878 - monet_disc_loss: 0.5780 - photo_disc_loss: 0.5732
# Epoch 74/120
# 300/300 [==============================] - 60s 201ms/step - monet_gen_loss: 2.6780 - photo_gen_loss: 2.7105 - monet_disc_loss: 0.5741 - photo_disc_loss: 0.5667
# Epoch 75/120
# 300/300 [==============================] - 60s 200ms/step - monet_gen_loss: 2.6443 - photo_gen_loss: 2.6879 - monet_disc_loss: 0.5855 - photo_disc_loss: 0.5688
# Epoch 76/120
# 300/300 [==============================] - 60s 200ms/step - monet_gen_loss: 2.6131 - photo_gen_loss: 2.6728 - monet_disc_loss: 0.5814 - photo_disc_loss: 0.5785
# Epoch 77/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.6404 - photo_gen_loss: 2.7001 - monet_disc_loss: 0.5854 - photo_disc_loss: 0.5654
# Epoch 78/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.6106 - photo_gen_loss: 2.6727 - monet_disc_loss: 0.5859 - photo_disc_loss: 0.5687
# Epoch 79/120
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 2.6059 - photo_gen_loss: 2.6694 - monet_disc_loss: 0.5911 - photo_disc_loss: 0.5765
# Epoch 80/120
# 300/300 [==============================] - 60s 202ms/step - monet_gen_loss: 2.5896 - photo_gen_loss: 2.6533 - monet_disc_loss: 0.5964 - photo_disc_loss: 0.5779
# Epoch 81/120
# 300/300 [==============================] - 61s 204ms/step - monet_gen_loss: 2.6782 - photo_gen_loss: 2.7319 - monet_disc_loss: 0.5885 - photo_disc_loss: 0.5586
# Epoch 82/120
# 300/300 [==============================] - 61s 204ms/step - monet_gen_loss: 2.6137 - photo_gen_loss: 2.6712 - monet_disc_loss: 0.5908 - photo_disc_loss: 0.5718
# Epoch 83/120
# 300/300 [==============================] - 62s 205ms/step - monet_gen_loss: 2.6356 - photo_gen_loss: 2.7094 - monet_disc_loss: 0.5849 - photo_disc_loss: 0.5679
# Epoch 84/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.0378 - photo_gen_loss: 3.0443 - monet_disc_loss: 0.5146 - photo_disc_loss: 0.4844
# Epoch 85/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.9474 - photo_gen_loss: 3.1237 - monet_disc_loss: 0.5569 - photo_disc_loss: 0.5050
# Epoch 86/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7198 - photo_gen_loss: 2.8268 - monet_disc_loss: 0.5854 - photo_disc_loss: 0.5445
# Epoch 87/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.7199 - photo_gen_loss: 2.8649 - monet_disc_loss: 0.5759 - photo_disc_loss: 0.5396
# Epoch 88/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.8276 - photo_gen_loss: 2.8861 - monet_disc_loss: 0.5596 - photo_disc_loss: 0.5348
# Epoch 89/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.8366 - photo_gen_loss: 2.9469 - monet_disc_loss: 0.5596 - photo_disc_loss: 0.5305
# Epoch 90/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.6846 - photo_gen_loss: 2.8027 - monet_disc_loss: 0.5836 - photo_disc_loss: 0.5384
# Epoch 91/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.6531 - photo_gen_loss: 2.7800 - monet_disc_loss: 0.5843 - photo_disc_loss: 0.5414
# Epoch 92/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.6802 - photo_gen_loss: 2.8112 - monet_disc_loss: 0.5818 - photo_disc_loss: 0.5514
# Epoch 93/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.6891 - photo_gen_loss: 2.8069 - monet_disc_loss: 0.5795 - photo_disc_loss: 0.5469
# Epoch 94/120
# 300/300 [==============================] - 58s 193ms/step - monet_gen_loss: 2.7488 - photo_gen_loss: 2.8559 - monet_disc_loss: 0.5671 - photo_disc_loss: 0.5385
# Epoch 95/120
# 300/300 [==============================] - 61s 202ms/step - monet_gen_loss: 2.7246 - photo_gen_loss: 2.8330 - monet_disc_loss: 0.5771 - photo_disc_loss: 0.5426
# Epoch 96/120
# 300/300 [==============================] - 60s 199ms/step - monet_gen_loss: 2.7002 - photo_gen_loss: 2.8128 - monet_disc_loss: 0.5825 - photo_disc_loss: 0.5476
# Epoch 97/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.6955 - photo_gen_loss: 2.8245 - monet_disc_loss: 0.5793 - photo_disc_loss: 0.5453
# Epoch 98/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.8287 - photo_gen_loss: 3.0908 - monet_disc_loss: 0.5685 - photo_disc_loss: 0.4861
# Epoch 99/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7069 - photo_gen_loss: 2.8554 - monet_disc_loss: 0.5797 - photo_disc_loss: 0.5415
# Epoch 100/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7481 - photo_gen_loss: 2.9694 - monet_disc_loss: 0.5666 - photo_disc_loss: 0.5121
# Epoch 101/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.7731 - photo_gen_loss: 2.9782 - monet_disc_loss: 0.5670 - photo_disc_loss: 0.5147
# Epoch 102/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7167 - photo_gen_loss: 2.9265 - monet_disc_loss: 0.5839 - photo_disc_loss: 0.5228
# Epoch 103/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.6995 - photo_gen_loss: 2.9095 - monet_disc_loss: 0.5865 - photo_disc_loss: 0.5254
# Epoch 104/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.6917 - photo_gen_loss: 2.8701 - monet_disc_loss: 0.5900 - photo_disc_loss: 0.5345
# Epoch 105/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.6647 - photo_gen_loss: 2.8185 - monet_disc_loss: 0.5865 - photo_disc_loss: 0.5559
# Epoch 106/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.6679 - photo_gen_loss: 2.8142 - monet_disc_loss: 0.5881 - photo_disc_loss: 0.5543
# Epoch 107/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.6633 - photo_gen_loss: 2.7845 - monet_disc_loss: 0.5982 - photo_disc_loss: 0.5476
# Epoch 108/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 2.7675 - photo_gen_loss: 2.8613 - monet_disc_loss: 0.5761 - photo_disc_loss: 0.5482
# Epoch 109/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.8655 - photo_gen_loss: 2.9182 - monet_disc_loss: 0.5478 - photo_disc_loss: 0.5458
# Epoch 110/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.1999 - photo_gen_loss: 3.0417 - monet_disc_loss: 0.4666 - photo_disc_loss: 0.4956
# Epoch 111/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 3.1964 - photo_gen_loss: 3.0813 - monet_disc_loss: 0.4987 - photo_disc_loss: 0.5089
# Epoch 112/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 3.0766 - photo_gen_loss: 3.1384 - monet_disc_loss: 0.5189 - photo_disc_loss: 0.4996
# Epoch 113/120
# 300/300 [==============================] - 59s 196ms/step - monet_gen_loss: 3.0643 - photo_gen_loss: 3.3185 - monet_disc_loss: 0.5418 - photo_disc_loss: 0.4834
# Epoch 114/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 2.8366 - photo_gen_loss: 3.0056 - monet_disc_loss: 0.5692 - photo_disc_loss: 0.5120
# Epoch 115/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.8217 - photo_gen_loss: 2.9110 - monet_disc_loss: 0.5649 - photo_disc_loss: 0.5395
# Epoch 116/120
# 300/300 [==============================] - 59s 197ms/step - monet_gen_loss: 2.7532 - photo_gen_loss: 2.8533 - monet_disc_loss: 0.5723 - photo_disc_loss: 0.5416
# Epoch 117/120
# 300/300 [==============================] - 59s 198ms/step - monet_gen_loss: 2.7438 - photo_gen_loss: 2.8455 - monet_disc_loss: 0.5728 - photo_disc_loss: 0.5532
# Epoch 118/120
# 300/300 [==============================] - 59s 195ms/step - monet_gen_loss: 2.7532 - photo_gen_loss: 2.8387 - monet_disc_loss: 0.5818 - photo_disc_loss: 0.5556
# Epoch 119/120
# 300/300 [==============================] - 58s 195ms/step - monet_gen_loss: 2.7469 - photo_gen_loss: 2.8319 - monet_disc_loss: 0.5848 - photo_disc_loss: 0.5566
# Epoch 120/120
# 300/300 [==============================] - 58s 194ms/step - monet_gen_loss: 2.7551 - photo_gen_loss: 2.8391 - monet_disc_loss: 0.5823 - photo_disc_loss: 0.5618

# %%
# !mkdir -p saved_model

# %%
monet_generator.save_weights('saved_model/Mon_Gen_weights_120.h5')

# %%
# !zip -r /content/Mon_Gen_weights_120.zip /content/saved_model/Mon_Gen_weights_120.h5

from google.colab import files
files.download("/content/Mon_Gen_weights_120.zip")
# Out:
#   adding: content/saved_model/Mon_Gen_weights_120.h5 (deflated 7%)

# %% [markdown]
# # Visualize our Monet-esque photos

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(photo_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %% [markdown]
# # Create submission file

# %%
# import PIL
# ! mkdir ../images

# %%
# i = 1
# with tqdm(total=len(photo_ds)) as pbar:
#     for img in photo_ds:
#         pbar.update
#         prediction = monet_generator(img, training=False)[0].numpy()
#         prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
#         im = PIL.Image.fromarray(prediction)
#         im.save("../images/" + str(i) + ".jpg")
#         i += 1

# %% [markdown]
# #Monet from personal photo

# %%
from google.colab import files
files.upload()

# %%
import cv2
import os
import random
import glob

# %%
! mkdir per_files
! mkdir per_files/img
! mv /content/*.jpg /content/per_files/img/
# Out:
# mkdir: cannot create directory ‘per_files’: File exists
# mkdir: cannot create directory ‘per_files/img’: File exists

# %%
PER_FILES="/content/per_files/"

# %%
def preproc(image):
    if image.shape[:2]!=IMAGE_SIZE:
      image = (tf.cast(image, tf.float32) / 127.5) - 1
      image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

# %%
def generator(file_dir):
    image_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preproc)
    image_generator = image_datagen.flow_from_directory(
    file_dir, target_size=IMAGE_SIZE, color_mode='rgb', batch_size=1,class_mode=None,shuffle=False)
    return image_generator

# %%
personnal_gen=generator(PER_FILES)
# Out:
# Found 2 images belonging to 2 classes.

# %%
nb_of_img=len(glob.glob("/content/per_files/img/*.jpg"))
print(nb_of_img)
for i, img in enumerate(personnal_gen):
    if i>=nb_of_img:
        break
    try:
        idx=personnal_gen.filenames[i:i+1][0]
        prediction = monet_generator(img, training=False)[0].numpy()
        prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
        prediction=cv2.cvtColor(prediction,cv2.COLOR_BGR2RGB)
        cv2.imwrite("/content/per_files/img/"+idx.split("/")[-1][:-4]+"monet.jpg",prediction)
    except:
        break
# Out:
# 2

# %% [markdown]
# #Cut and paste

# %%
def divide_img(img_path,fn, crop_size=256):
    '''
    Will extract 256x256 images covering the whole original image
    with some overlap between images
    '''
    
    img = cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_height, img_width = img.shape[:2]
    
    x_img_origins = [crop_size*i for i in range(img_height//crop_size)]
    y_img_origins = [crop_size*i for i in range(img_width//crop_size)]
    img_list = []
    new_dir="/content/per_files/img/"+os.path.basename(img_path).split(".")[0]+"_part"
    res_dir="/content/per_files/img/"+os.path.basename(img_path).split(".")[0]+"_res"
    os.mkdir(new_dir)
    os.mkdir(res_dir)
    for x in x_img_origins:
        for y in y_img_origins:
            img_list.append(img[x:x+crop_size , y:y+crop_size,:])
            cv2.imwrite(new_dir+"/"+str(fn)+"-"+str(x)+"-"+str(y)+".png",img[x:x+crop_size , y:y+crop_size,:])
    return img_list

# %%
i=0
for img in glob.glob(PER_FILES+"*.jpg"):
    divide_img(img,i)
    i+=1

# %%
def preproc(image):
    if image.shape[:2]!=IMAGE_SIZE:
      image = (tf.cast(image, tf.float32) / 127.5) - 1
      image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

# %%
def generator(file_dir):
    image_datagen = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preproc)
    image_generator = image_datagen.flow_from_directory(
    file_dir, target_size=IMAGE_SIZE, color_mode='rgb', batch_size=1,class_mode=None,shuffle=False)
    return image_generator

# %%
personnal_gen=generator(PER_FILES+"img/")

# %%
nb_of_img=len(glob.glob("/content/per_files/img/*/*.png"))
for i, img in enumerate(personnal_gen):
    if i>=nb_of_img:
        break
    try:
        idx=personnal_gen.filenames[i:i+1][0]
        dir_to_save=idx.split("/")[0][:-4]+"res/"
        prediction = monet_generator(img, training=False)[0].numpy()
        prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
        cv2.imwrite(PER_FILES+"img/"+dir_to_save+idx.split("/")[-1],prediction)
    except:
        break

# %%
def glue_img_together(save_dir=PER_FILES,per_files=PER_FILES+"img/",crop_size=256):
    for dir in glob.glob(per_files+"/*"):
        if dir.split("/")[-1][-3:]=="res":
            parts=glob.glob(dir+"/*.png")
            size=cv2.imread(save_dir+dir.split("/")[-1][:-4]+".jpg").shape
            print(size)
            final_image =  np.zeros(size,dtype=np.uint8)
            for img in parts:
                fn,x,y=img.split('/')[-1].split('.')[0].split('-')
                x=int(x)
                y=int(y)
                
                final_image[x:x+crop_size , y:y+crop_size,:]=cv2.cvtColor(cv2.imread(img),cv2.COLOR_BGR2RGB)
            cv2.imwrite(save_dir+dir.split("/")[-1][:-4]+"monet.jpg",final_image)
glue_img_together()
